# %% [markdown]
# # Face Generation
#
# In this project, you'll define and train a DCGAN on a dataset of faces. Your goal is to get a generator network to generate *new* images of faces that look as realistic as possible!
#
# The project will be broken down into a series of tasks from **loading in data to defining and training adversarial networks**. At the end of the notebook, you'll be able to visualize the results of your trained Generator to see how it performs; your generated samples should look like fairly realistic faces with small amounts of noise.
#
# ### Get the Data
#
# You'll be using the [CelebFaces Attributes Dataset (CelebA)](http://mmlab.ie.cuhk.edu.hk/projects/CelebA.html) to train your adversarial networks.
#
# This dataset is more complex than the number datasets (like MNIST or SVHN) you've been working with, and so, you should prepare to define deeper networks and train them for a longer time to get good results. It is suggested that you utilize a GPU for training.
#
# ### Pre-processed Data
#
# Since the project's main focus is on building the GANs, we've done *some* of the pre-processing for you. Each of the CelebA images has been cropped to remove parts of the image that don't include a face, then resized down to 64x64x3 NumPy images. Some sample data is show below.
#
# <img src='assets/processed_face_data.png' width=60% />
#
# > If you are working locally, you can download this data [by clicking here](https://s3.amazonaws.com/video.udacity-data.com/topher/2018/November/5be7eb6f_processed-celeba-small/processed-celeba-small.zip)
#
# This is a zip file that you'll need to extract in the home directory of this notebook for further loading and processing. After extracting the data, you should be left with a directory of data `processed_celeba_small/`

# %%
# can comment out after executing
#!unzip processed_celeba_small.zip

# %%
data_dir = 'processed_celeba_small/'

"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
import pickle as pkl
import matplotlib.pyplot as plt
import numpy as np
import problem_unittests as tests
#import helper

# %matplotlib inline

# %% [markdown]
# ## Visualize the CelebA Data
#
# The [CelebA](http://mmlab.ie.cuhk.edu.hk/projects/CelebA.html) dataset contains over 200,000 celebrity images with annotations. Since you're going to be generating faces, you won't need the annotations, you'll only need the images. Note that these are color images with [3 color channels (RGB)](https://en.wikipedia.org/wiki/Channel_(digital_image)#RGB_Images) each.
#
# ### Pre-process and Load the Data
#
# Since the project's main focus is on building the GANs, we've done *some* of the pre-processing for you. Each of the CelebA images has been cropped to remove parts of the image that don't include a face, then resized down to 64x64x3 NumPy images. This *pre-processed* dataset is a smaller subset of the very large CelebA data.
#
# > There are a few other steps that you'll need to **transform** this data and create a **DataLoader**.
#
# #### Exercise: Complete the following `get_dataloader` function, such that it satisfies these requirements:
#
# * Your images should be square, Tensor images of size `image_size x image_size` in the x and y dimension.
# * Your function should return a DataLoader that shuffles and batches these Tensor images.
#
# #### ImageFolder
#
# To create a dataset given a directory of images, it's recommended that you use PyTorch's [ImageFolder](https://pytorch.org/docs/stable/torchvision/datasets.html#imagefolder) wrapper, with a root directory `processed_celeba_small/` and data transformation passed in.

# %%
# necessary imports
import torch
from torchvision import datasets
from torchvision import transforms
import os

# %%
from torch.utils.data import DataLoader

def get_dataloader(batch_size, image_size, data_dir='processed_celeba_small/'):
    """
    Batch the neural network data using DataLoader
    :param batch_size: The size of each batch; the number of images in a batch
    :param img_size: The square size of the image data (x, y)
    :param data_dir: Directory where image data is located
    :return: DataLoader with batched data
    """
    # TODO: Implement function and return a dataloader
    # resize and normalize the images
    transform = transforms.Compose([transforms.Resize(image_size), # resize to 128x128
                                    transforms.CenterCrop(image_size),
                                    transforms.RandomHorizontalFlip(),
                                    transforms.ToTensor()])
    # get training and test directories
    image_path = './' + data_dir
    train_path = os.path.join(image_path)

    # define datasets using ImageFolder
    train_dataset = datasets.ImageFolder(train_path, transform)

    num_workers=0
    # create and return DataLoaders
    train_loader = DataLoader(dataset=train_dataset, batch_size=batch_size, shuffle=True, num_workers=num_workers)

    return train_loader

# %% [markdown]
# ## Create a DataLoader
#
# #### Exercise: Create a DataLoader `celeba_train_loader` with appropriate hyperparameters.
#
# Call the above function and create a dataloader to view images.
# * You can decide on any reasonable `batch_size` parameter
# * Your `image_size` **must be** `32`. Resizing the data to a smaller size will make for faster training, while still creating convincing images of faces!

# %%
# Define function hyperparameters
batch_size = 128
img_size = 32

"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
# Call your function and get a dataloader
celeba_train_loader = get_dataloader(batch_size, img_size)

# %% [markdown]
# Next, you can view some images! You should seen square images of somewhat-centered faces.
#
# Note: You'll need to convert the Tensor images into a NumPy type and transpose the dimensions to correctly display an image, suggested `imshow` code is below, but it may not be perfect.

# %%
# helper display function
def imshow(img):
    npimg = img.numpy()
    plt.imshow(np.transpose(npimg, (1, 2, 0)))

"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
# obtain one batch of training images
dataiter = iter(celeba_train_loader)
images, _ = dataiter.next() # _ for no labels

# plot the images in the batch, along with the corresponding labels
fig = plt.figure(figsize=(20, 4))
plot_size=20
for idx in np.arange(plot_size):
    ax = fig.add_subplot(2, plot_size/2, idx+1, xticks=[], yticks=[])
    imshow(images[idx])

# %% [markdown]
# #### Exercise: Pre-process your image data and scale it to a pixel range of -1 to 1
#
# You need to do a bit of pre-processing; you know that the output of a `tanh` activated generator will contain pixel values in a range from -1 to 1, and so, we need to rescale our training images to a range of -1 to 1. (Right now, they are in a range from 0-1.)

# %%
# TODO: Complete the scale function
def scale(x, feature_range=(-1, 1)):
    ''' Scale takes in an image x and returns that image, scaled
       with a feature_range of pixel values from -1 to 1. 
       This function assumes that the input x is already scaled from 0-1.'''
    # assume x is scaled to (0, 1)
    # scale to feature_range and return scaled x
    min, max = feature_range
    x = x * (max - min) + min
    return x

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
# check scaled range
# should be close to -1 to 1
img = images[0]
scaled_img = scale(img)

print('Min: ', scaled_img.min())
print('Max: ', scaled_img.max())
# Out:
# Min:  tensor(-0.9765)
# Max:  tensor(0.9922)

# %% [markdown]
# ---
# # Define the Model
#
# A GAN is comprised of two adversarial networks, a discriminator and a generator.
#
# ## Discriminator
#
# Your first task will be to define the discriminator. This is a convolutional classifier like you've built before, only without any maxpooling layers. To deal with this complex data, it's suggested you use a deep network with **normalization**. You are also allowed to create any helper functions that may be useful.
#
# #### Exercise: Complete the Discriminator class
# * The inputs to the discriminator are 32x32x3 tensor images
# * The output should be a single value that will indicate whether a given image is real or fake

# %%
import torch.nn as nn
import torch.nn.functional as F

# helper conv function
def conv(in_channels, out_channels, kernel_size, stride=2, padding=1, batch_norm=True):
    """Creates a convolutional layer, with optional batch normalization.
    """
    layers = []     ## ^2 downsampling 32*32 → 16*16 
    conv_layer = nn.Conv2d(in_channels, out_channels, 
                        kernel_size, stride, padding, bias=False)
    
    # append conv layer
    layers.append(conv_layer)

    if batch_norm:
        # append batchnorm layer
        layers.append(nn.BatchNorm2d(out_channels))
     
    # using Sequential container
    return nn.Sequential(*layers)

# %%
class Discriminator(nn.Module):

    def __init__(self, conv_dim=32):
        """
        Initialize the Discriminator Module
        :param conv_dim: The depth of the first convolutional layer
        """
        super(Discriminator, self).__init__()

        # complete init function
        self.conv_dim = conv_dim
        # 32x32 input, kerner size=4
        self.conv1 = conv(3, conv_dim, 4, batch_norm=False)  # first layer, no batch_norm
        # 16x16 out
        self.conv2 = conv(conv_dim, conv_dim*2, 4)
        # 8x8 out
        self.conv3 = conv(conv_dim*2, conv_dim*4, 4)
        # 4x4 out        
        # final, fully-connected layer
        self.fc = nn.Linear(conv_dim*4*4*4, 1)
        

    def forward(self, x):
        """
        Forward propagation of the neural network
        :param x: The input to the neural network     
        :return: Discriminator logits; the output of the neural network
        """
        # define feedforward behavior
        # all hidden layers + leaky relu activation
        out = F.leaky_relu(self.conv1(x), 0.2)
        out = F.leaky_relu(self.conv2(out), 0.2)
        out = F.leaky_relu(self.conv3(out), 0.2)       
        # flatten
        out = out.view(-1, self.conv_dim*4*4*4)        
        # final output layer
        out = self.fc(out)        
        return out
        return x


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_discriminator(Discriminator)
# Out:
# Tests Passed

# %% [markdown]
# ## Generator
#
# The generator should upsample an input and generate a *new* image of the same size as our training data `32x32x3`. This should be mostly transpose convolutional layers with normalization applied to the outputs.
#
# #### Exercise: Complete the Generator class
# * The inputs to the generator are vectors of some length `z_size`
# * The output should be a image of shape `32x32x3`

# %%
# helper deconv function
def deconv(in_channels, out_channels, kernel_size, stride=2, padding=1, batch_norm=True):
    """Creates a transposed-convolutional layer, with optional batch normalization.
    """
    # create a sequence of transpose + optional batch norm layers
    layers = []
    transpose_conv_layer = nn.ConvTranspose2d(in_channels, out_channels, 
                        kernel_size, stride, padding, bias=False)
    # append transpose convolutional layer
    layers.append(transpose_conv_layer)
    
    if batch_norm:
        # append batchnorm layer
        layers.append(nn.BatchNorm2d(out_channels))
        
    return nn.Sequential(*layers)

class Generator(nn.Module):
    
    def __init__(self, z_size, conv_dim):
        """
        Initialize the Generator Module
        :param z_size: The length of the input latent vector, z
        :param conv_dim: The depth of the inputs to the *last* transpose convolutional layer
        """
        super(Generator, self).__init__()

        # complete init function
        self.conv_dim = conv_dim       
        # first, fully-connected layer
        self.fc = nn.Linear(z_size, conv_dim*4*4*4)#128*16
        # transpose conv layers
        self.t_conv1 = deconv(conv_dim*4, conv_dim*2, 4)
        self.t_conv2 = deconv(conv_dim*2, conv_dim, 4)
        self.t_conv3 = deconv(conv_dim, 3, 4, batch_norm=False)        # 32*32
        

    def forward(self, x):
        """
        Forward propagation of the neural network
        :param x: The input to the neural network     
        :return: A 32x32x3 Tensor image as output
        """
        # define feedforward behavior
        # fully-connected + reshape 
        out = self.fc(x)
        out = out.view(-1, self.conv_dim*4, 4, 4) # (batch_size, depth, 4, 4)        
        # hidden transpose conv layers + relu
        out = F.relu(self.t_conv1(out))
        out = F.relu(self.t_conv2(out))        
        # last layer + tanh activation
        out = self.t_conv3(out)
        out = F.tanh(out)     #32*32*3
        return out

"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_generator(Generator)
# Out:
# Tests Passed

# %% [markdown]
# ## Initialize the weights of your networks
#
# To help your models converge, you should initialize the weights of the convolutional and linear layers in your model. From reading the [original DCGAN paper](https://arxiv.org/pdf/1511.06434.pdf), they say:
# > All weights were initialized from a zero-centered Normal distribution with standard deviation 0.02.
#
# So, your next task will be to define a weight initialization function that does just this!
#
# You can refer back to the lesson on weight initialization or even consult existing model code, such as that from [the `networks.py` file in CycleGAN Github repository](https://github.com/junyanz/pytorch-CycleGAN-and-pix2pix/blob/master/models/networks.py) to help you complete this function.
#
# #### Exercise: Complete the weight initialization function
#
# * This should initialize only **convolutional** and **linear** layers
# * Initialize the weights to a normal distribution, centered around 0, with a standard deviation of 0.02.
# * The bias terms, if they exist, may be left alone or set to 0.

# %%
from torch.nn import init
def weights_init_normal(m):
    """
    Applies initial weights to certain layers in a model .
    The weights are taken from a normal distribution 
    with mean = 0, std dev = 0.02.
    :param m: A module or layer in a network   
    
    """
    # classname will be something like:
    # `Conv`, `BatchNorm2d`, `Linear`, etc.
    classname = m.__class__.__name__
    # define the initialization function
    
    if hasattr(m, 'weight') and (classname.find('Conv') != -1 or classname.find('Linear') != -1):
        init.normal_(m.weight.data, mean=0.0, std=0.02)
        if hasattr(m, 'bias') and m.bias is not None:
            init.constant_(m.bias.data, 0.0)

# %% [markdown]
# ## Build complete network
#
# Define your models' hyperparameters and instantiate the discriminator and generator from the classes defined above. Make sure you've passed in the correct input arguments.

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
def build_network(d_conv_dim, g_conv_dim, z_size):
    # define discriminator and generator
    D = Discriminator(d_conv_dim)
    G = Generator(z_size=z_size, conv_dim=g_conv_dim)

    # initialize model weights
    D.apply(weights_init_normal)
    G.apply(weights_init_normal)

    print(D)
    print()
    print(G)
    
    return D, G

# %% [markdown]
# #### Exercise: Define model hyperparameters

# %%
# Define model hyperparams
d_conv_dim = 32
g_conv_dim = 32
z_size = 100

"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
D, G = build_network(d_conv_dim, g_conv_dim, z_size)
# Out:
# Discriminator(
#   (conv1): Sequential(
#     (0): Conv2d(3, 32, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1), bias=False)
#   )
#   (conv2): Sequential(
#     (0): Conv2d(32, 64, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1), bias=False)
#     (1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   )
#   (conv3): Sequential(
#     (0): Conv2d(64, 128, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1), bias=False)
#     (1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   )
#   (fc): Linear(in_features=2048, out_features=1, bias=True)
# )
#
# Generator(
#   (fc): Linear(in_features=100, out_features=2048, bias=True)
#   (t_conv1): Sequential(
#     (0): ConvTranspose2d(128, 64, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1), bias=False)
#     (1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   )
#   (t_conv2): Sequential(
#     (0): ConvTranspose2d(64, 32, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1), bias=False)
#     (1): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   )
#   (t_conv3): Sequential(
#     (0): ConvTranspose2d(32, 3, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1), bias=False)
#   )
# )

# %% [markdown]
# ### Training on GPU
#
# Check if you can train on GPU. Here, we'll set this as a boolean variable `train_on_gpu`. Later, you'll be responsible for making sure that
# >* Models,
# * Model inputs, and
# * Loss function arguments
#
# Are moved to GPU, where appropriate.

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
import torch

# Check for a GPU
train_on_gpu = torch.cuda.is_available()
if not train_on_gpu:
    print('No GPU found. Please use a GPU to train your neural network.')
else:
    print('Training on GPU!')
# Out:
# Training on GPU!

# %% [markdown]
# ---
# ## Discriminator and Generator Losses
#
# Now we need to calculate the losses for both types of adversarial networks.
#
# ### Discriminator Losses
#
# > * For the discriminator, the total loss is the sum of the losses for real and fake images, `d_loss = d_real_loss + d_fake_loss`.
# * Remember that we want the discriminator to output 1 for real images and 0 for fake images, so we need to set up the losses to reflect that.
#
#
# ### Generator Loss
#
# The generator loss will look similar only with flipped labels. The generator's goal is to get the discriminator to *think* its generated images are *real*.
#
# #### Exercise: Complete real and fake loss functions
#
# **You may choose to use either cross entropy or a least squares error loss to complete the following `real_loss` and `fake_loss` functions.**

# %%
def real_loss(D_out, smooth=0.0):
    '''Calculates how close discriminator outputs are to being real.
       param, D_out: discriminator logits
       return: real loss'''
    batch_size = D_out.size(0)
    # label smoothing
    labels = torch.ones(batch_size) * (1 - smooth)# real labels = 1
    # move labels to GPU if available     
    if train_on_gpu:
        labels = labels.cuda()

    # binary cross entropy with logits loss
    criterion = nn.BCEWithLogitsLoss()
    # calculate loss
    loss = criterion(D_out.squeeze(), labels)
    return loss

def fake_loss(D_out):
    '''Calculates how close discriminator outputs are to being fake.
       param, D_out: discriminator logits
       return: fake loss'''
    batch_size = D_out.size(0)
    labels = torch.zeros(batch_size) # fake labels = 0
    if train_on_gpu:
        labels = labels.cuda()
    criterion = nn.BCEWithLogitsLoss()
    # calculate loss
    loss = criterion(D_out.squeeze(), labels)
    return loss

# %% [markdown]
# ## Optimizers
#
# #### Exercise: Define optimizers for your Discriminator (D) and Generator (G)
#
# Define optimizers for your models with appropriate hyperparameters.

# %%
import torch.optim as optim

#hyper- params
lr = 0.0002
beta1=0.5
beta2=0.999 # default value
# Create optimizers for the discriminator D and generator G
d_optimizer = optim.Adam(D.parameters(), lr, [beta1, beta2])
g_optimizer = optim.Adam(G.parameters(), lr, [beta1, beta2])

# %% [markdown]
# ---
# ## Training
#
# Training will involve alternating between training the discriminator and the generator. You'll use your functions `real_loss` and `fake_loss` to help you calculate the discriminator losses.
#
# * You should train the discriminator by alternating on real and fake images
# * Then the generator, which tries to trick the discriminator and should have an opposing loss function
#
#
# #### Saving Samples
#
# You've been given some code to print out some loss statistics and save some generated "fake" samples.

# %% [markdown]
# #### Exercise: Complete the training function
#
# Keep in mind that, if you've moved your models to GPU, you'll also have to move any model inputs to GPU.

# %%
def train(D, G, n_epochs, print_every=50):
    '''Trains adversarial networks for some number of epochs
       param, D: the discriminator network
       param, G: the generator network
       param, n_epochs: number of epochs to train for
       param, print_every: when to print and record the models' losses
       return: D and G losses'''
    
    # move models to GPU
    if train_on_gpu:
        D.cuda()
        G.cuda()

    # keep track of loss and generated, "fake" samples
    samples = []
    losses = []

    # Get some fixed data for sampling. These are images that are held
    # constant throughout training, and allow us to inspect the model's performance
    sample_size=16
    fixed_z = np.random.uniform(-1, 1, size=(sample_size, z_size))
    fixed_z = torch.from_numpy(fixed_z).float()
    # move z to GPU if available
    if train_on_gpu:
        fixed_z = fixed_z.cuda()

    # epoch training loop
    for epoch in range(n_epochs):

        # batch training loop
        for batch_i, (real_images, _) in enumerate(celeba_train_loader):

            batch_size = real_images.size(0)
            real_images = scale(real_images)

            # ===============================================
            #         YOUR CODE HERE: TRAIN THE NETWORKS
            # ===============================================
            d_optimizer.zero_grad()   
            # 1. Train the discriminator on real and fake images
            if train_on_gpu:
                real_images = real_images.cuda()       
            D_real = D(real_images)
            smooth =0.1  ## smoothing 
            d_real_loss = real_loss(D_real, smooth)  
            # 2. Train with fake images       
            # Generate fake images
            z = np.random.uniform(-1, 1, size=(batch_size, z_size))
            z = torch.from_numpy(z).float()
            # move x to GPU, if available
            if train_on_gpu:
                z = z.cuda()
            fake_images = G(z)        
            # Compute the discriminator losses on fake images            
            D_fake = D(fake_images)
            d_fake_loss = fake_loss(D_fake)        
            # add up loss and perform backprop
            d_loss = d_real_loss + d_fake_loss
            d_loss.backward()
            d_optimizer.step()
            
            # 2. Train the generator with an adversarial loss
            g_optimizer.zero_grad()       
            # 1. Train with fake images and flipped labels        
            # Generate fake images
            z = np.random.uniform(-1, 1, size=(batch_size, z_size))
            z = torch.from_numpy(z).float()
            if train_on_gpu:
                z = z.cuda()
            fake_images = G(z)        
            # Compute the discriminator losses on fake images 
            # using flipped labels!
            D_fake = D(fake_images)
            g_loss = real_loss(D_fake) # use real loss to flip labels        
            # perform backprop
            g_loss.backward()
            g_optimizer.step()
            
            
            # ===============================================
            #              END OF YOUR CODE
            # ===============================================

            # Print some loss stats
            if batch_i % print_every == 0:
                # append discriminator loss and generator loss
                losses.append((d_loss.item(), g_loss.item()))
                # print discriminator and generator loss
                print('Epoch [{:5d}/{:5d}] | d_loss: {:6.4f} | g_loss: {:6.4f}'.format(
                        epoch+1, n_epochs, d_loss.item(), g_loss.item()))


        ## AFTER EACH EPOCH##    
        # this code assumes your generator is named G, feel free to change the name
        # generate and save sample, fake images
        G.eval() # for generating samples
        samples_z = G(fixed_z)
        samples.append(samples_z)
        G.train() # back to training mode

    # Save training generator samples
    with open('train_samples.pkl', 'wb') as f:
        pkl.dump(samples, f)
    
    # finally return losses
    return losses

# %% [markdown]
# Set your number of training epochs and train your GAN!

# %%
# set number of epochs 
n_epochs = 50


"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
# call training function
losses = train(D, G, n_epochs=n_epochs)
# Out:
# Epoch [    1/   50] | d_loss: 0.8465 | g_loss: 2.6743
# Epoch [    1/   50] | d_loss: 1.0803 | g_loss: 2.4299
# Epoch [    1/   50] | d_loss: 1.1893 | g_loss: 1.2848
# Epoch [    1/   50] | d_loss: 1.1024 | g_loss: 1.5413
# Epoch [    1/   50] | d_loss: 1.0709 | g_loss: 1.1813
# Epoch [    1/   50] | d_loss: 1.2211 | g_loss: 2.1153
# Epoch [    1/   50] | d_loss: 1.1287 | g_loss: 1.2123
# Epoch [    1/   50] | d_loss: 1.0660 | g_loss: 1.2855
# Epoch [    1/   50] | d_loss: 1.1766 | g_loss: 1.0678
# Epoch [    1/   50] | d_loss: 1.1321 | g_loss: 1.0953
# Epoch [    1/   50] | d_loss: 1.1692 | g_loss: 0.9265
# Epoch [    1/   50] | d_loss: 1.2204 | g_loss: 1.3086
# Epoch [    1/   50] | d_loss: 1.2499 | g_loss: 0.9932
# Epoch [    1/   50] | d_loss: 1.1817 | g_loss: 0.9446
# Epoch [    1/   50] | d_loss: 1.1788 | g_loss: 1.0472
# Epoch [    2/   50] | d_loss: 1.2674 | g_loss: 1.1602
# Epoch [    2/   50] | d_loss: 1.2043 | g_loss: 1.0200
# Epoch [    2/   50] | d_loss: 1.1073 | g_loss: 1.2963
# Epoch [    2/   50] | d_loss: 1.2815 | g_loss: 1.3198
# Epoch [    2/   50] | d_loss: 1.1091 | g_loss: 1.3298
# Epoch [    2/   50] | d_loss: 1.2903 | g_loss: 1.2384
# Epoch [    2/   50] | d_loss: 1.2197 | g_loss: 0.9599
# Epoch [    2/   50] | d_loss: 1.1728 | g_loss: 1.0927
# Epoch [    2/   50] | d_loss: 1.2954 | g_loss: 0.9001
# Epoch [    2/   50] | d_loss: 1.3174 | g_loss: 0.9404
# Epoch [    2/   50] | d_loss: 1.1247 | g_loss: 1.0179
# Epoch [    2/   50] | d_loss: 1.2094 | g_loss: 1.4793
# Epoch [    2/   50] | d_loss: 1.3207 | g_loss: 1.1588
# Epoch [    2/   50] | d_loss: 1.2371 | g_loss: 0.9611
# Epoch [    2/   50] | d_loss: 1.3395 | g_loss: 1.1350
# Epoch [    3/   50] | d_loss: 1.2011 | g_loss: 0.9229
# Epoch [    3/   50] | d_loss: 1.1968 | g_loss: 1.0130
# Epoch [    3/   50] | d_loss: 1.2941 | g_loss: 0.7990
# Epoch [    3/   50] | d_loss: 1.2268 | g_loss: 1.1110
# Epoch [    3/   50] | d_loss: 1.2289 | g_loss: 1.3515
# Epoch [    3/   50] | d_loss: 1.1830 | g_loss: 1.0183
# Epoch [    3/   50] | d_loss: 1.0919 | g_loss: 1.1435
# Epoch [    3/   50] | d_loss: 1.1494 | g_loss: 0.9287
# Epoch [    3/   50] | d_loss: 1.2026 | g_loss: 0.7082
# Epoch [    3/   50] | d_loss: 0.9587 | g_loss: 1.6089
# Epoch [    3/   50] | d_loss: 1.1462 | g_loss: 1.2509
# Epoch [    3/   50] | d_loss: 1.2076 | g_loss: 0.8872
# Epoch [    3/   50] | d_loss: 1.0449 | g_loss: 1.2956
# Epoch [    3/   50] | d_loss: 1.1827 | g_loss: 1.0749
# Epoch [    3/   50] | d_loss: 1.2788 | g_loss: 0.7070
# Epoch [    4/   50] | d_loss: 1.1807 | g_loss: 1.2010
# Epoch [    4/   50] | d_loss: 1.0919 | g_loss: 1.3255
# Epoch [    4/   50] | d_loss: 1.2119 | g_loss: 0.8893
# Epoch [    4/   50] | d_loss: 1.4371 | g_loss: 0.4107
# Epoch [    4/   50] | d_loss: 1.0559 | g_loss: 1.2834
# Epoch [    4/   50] | d_loss: 1.1203 | g_loss: 0.9185
# Epoch [    4/   50] | d_loss: 1.0800 | g_loss: 1.3023
# Epoch [    4/   50] | d_loss: 1.2197 | g_loss: 1.3247
# Epoch [    4/   50] | d_loss: 1.2267 | g_loss: 1.1376
# Epoch [    4/   50] | d_loss: 1.1102 | g_loss: 1.3158
# Epoch [    4/   50] | d_loss: 1.2903 | g_loss: 1.2043
# Epoch [    4/   50] | d_loss: 1.1494 | g_loss: 0.8732
# Epoch [    4/   50] | d_loss: 1.3327 | g_loss: 1.5373
# Epoch [    4/   50] | d_loss: 1.0841 | g_loss: 1.1397
# Epoch [    4/   50] | d_loss: 1.2649 | g_loss: 0.6963
# Epoch [    5/   50] | d_loss: 1.1784 | g_loss: 1.1233
# Epoch [    5/   50] | d_loss: 1.2282 | g_loss: 0.5698
# Epoch [    5/   50] | d_loss: 1.1527 | g_loss: 0.9941
# Epoch [    5/   50] | d_loss: 1.1023 | g_loss: 1.1112
# Epoch [    5/   50] | d_loss: 1.1909 | g_loss: 1.4187
# Epoch [    5/   50] | d_loss: 1.1533 | g_loss: 0.9756
# Epoch [    5/   50] | d_loss: 1.0825 | g_loss: 1.3611
# Epoch [    5/   50] | d_loss: 1.3644 | g_loss: 0.3095
# Epoch [    5/   50] | d_loss: 1.0201 | g_loss: 1.2876
# Epoch [    5/   50] | d_loss: 1.1092 | g_loss: 1.1421
# Epoch [    5/   50] | d_loss: 1.1375 | g_loss: 1.5524
# Epoch [    5/   50] | d_loss: 1.2533 | g_loss: 0.6142
# Epoch [    5/   50] | d_loss: 1.1650 | g_loss: 1.8587
# Epoch [    5/   50] | d_loss: 1.4671 | g_loss: 0.5612
# Epoch [    5/   50] | d_loss: 1.1866 | g_loss: 1.2083
# Epoch [    6/   50] | d_loss: 1.1846 | g_loss: 1.0677
# Epoch [    6/   50] | d_loss: 1.1850 | g_loss: 1.0649
# Epoch [    6/   50] | d_loss: 1.1877 | g_loss: 1.4631
# Epoch [    6/   50] | d_loss: 1.1092 | g_loss: 1.2313
# Epoch [    6/   50] | d_loss: 1.0855 | g_loss: 1.0368
# Epoch [    6/   50] | d_loss: 1.0473 | g_loss: 1.2609
# Epoch [    6/   50] | d_loss: 1.1074 | g_loss: 1.2802
# Epoch [    6/   50] | d_loss: 0.9927 | g_loss: 1.3692
# Epoch [    6/   50] | d_loss: 1.1527 | g_loss: 1.7042
# Epoch [    6/   50] | d_loss: 1.1009 | g_loss: 0.9448
# Epoch [    6/   50] | d_loss: 0.9984 | g_loss: 0.9800
# Epoch [    6/   50] | d_loss: 1.1061 | g_loss: 1.1403
# Epoch [    6/   50] | d_loss: 1.0771 | g_loss: 1.1330
# Epoch [    6/   50] | d_loss: 1.1694 | g_loss: 1.5020
# Epoch [    6/   50] | d_loss: 1.1063 | g_loss: 1.3885
# Epoch [    7/   50] | d_loss: 1.0952 | g_loss: 1.1783
# Epoch [    7/   50] | d_loss: 1.1975 | g_loss: 0.8698
# Epoch [    7/   50] | d_loss: 1.1049 | g_loss: 1.4352
# Epoch [    7/   50] | d_loss: 1.0828 | g_loss: 1.2032
# Epoch [    7/   50] | d_loss: 1.1315 | g_loss: 0.6885
# Epoch [    7/   50] | d_loss: 1.0362 | g_loss: 1.3501
# Epoch [    7/   50] | d_loss: 0.9975 | g_loss: 1.4853
# Epoch [    7/   50] | d_loss: 1.0819 | g_loss: 1.4623
# Epoch [    7/   50] | d_loss: 1.1203 | g_loss: 1.2242
# Epoch [    7/   50] | d_loss: 1.0766 | g_loss: 1.3401
# Epoch [    7/   50] | d_loss: 1.1577 | g_loss: 0.8413
# Epoch [    7/   50] | d_loss: 0.9701 | g_loss: 1.2177
# Epoch [    7/   50] | d_loss: 1.0484 | g_loss: 1.4221
# Epoch [    7/   50] | d_loss: 1.0739 | g_loss: 1.4628
# Epoch [    7/   50] | d_loss: 1.0076 | g_loss: 1.4461
# Epoch [    8/   50] | d_loss: 1.0167 | g_loss: 1.0902
# Epoch [    8/   50] | d_loss: 1.1540 | g_loss: 1.8071
# Epoch [    8/   50] | d_loss: 1.0221 | g_loss: 1.1886
# Epoch [    8/   50] | d_loss: 1.0840 | g_loss: 0.9432
# Epoch [    8/   50] | d_loss: 1.0438 | g_loss: 1.2324
# Epoch [    8/   50] | d_loss: 1.1200 | g_loss: 1.0944
# Epoch [    8/   50] | d_loss: 1.0459 | g_loss: 1.0523
# Epoch [    8/   50] | d_loss: 1.2058 | g_loss: 1.7162
# Epoch [    8/   50] | d_loss: 1.1103 | g_loss: 1.4017
# Epoch [    8/   50] | d_loss: 0.9506 | g_loss: 1.2406
# Epoch [    8/   50] | d_loss: 1.3676 | g_loss: 1.9901
# Epoch [    8/   50] | d_loss: 1.0808 | g_loss: 1.7465
# Epoch [    8/   50] | d_loss: 1.1560 | g_loss: 1.3368
# Epoch [    8/   50] | d_loss: 1.2586 | g_loss: 1.8233
# Epoch [    8/   50] | d_loss: 1.0212 | g_loss: 1.0750
# Epoch [    9/   50] | d_loss: 1.0203 | g_loss: 1.1715
# Epoch [    9/   50] | d_loss: 1.1380 | g_loss: 1.0849
# Epoch [    9/   50] | d_loss: 1.0345 | g_loss: 1.1321
# Epoch [    9/   50] | d_loss: 1.0574 | g_loss: 1.2209
# Epoch [    9/   50] | d_loss: 1.0790 | g_loss: 1.4988
# Epoch [    9/   50] | d_loss: 1.0214 | g_loss: 1.1126
# Epoch [    9/   50] | d_loss: 1.2563 | g_loss: 1.6617
# Epoch [    9/   50] | d_loss: 1.1051 | g_loss: 0.7453
# Epoch [    9/   50] | d_loss: 1.2041 | g_loss: 0.8041
# Epoch [    9/   50] | d_loss: 1.0236 | g_loss: 1.2300
# Epoch [    9/   50] | d_loss: 0.9867 | g_loss: 1.2996
# Epoch [    9/   50] | d_loss: 0.9707 | g_loss: 1.5212
# Epoch [    9/   50] | d_loss: 1.1454 | g_loss: 1.1201
# Epoch [    9/   50] | d_loss: 1.0261 | g_loss: 1.0714
# Epoch [    9/   50] | d_loss: 1.2352 | g_loss: 2.0664
# Epoch [   10/   50] | d_loss: 1.0879 | g_loss: 1.0828
# Epoch [   10/   50] | d_loss: 1.0430 | g_loss: 0.9860
# Epoch [   10/   50] | d_loss: 1.1868 | g_loss: 1.7439
# Epoch [   10/   50] | d_loss: 1.2135 | g_loss: 2.0305
# Epoch [   10/   50] | d_loss: 1.0530 | g_loss: 1.0602
# Epoch [   10/   50] | d_loss: 1.1414 | g_loss: 1.6817
# Epoch [   10/   50] | d_loss: 1.0368 | g_loss: 1.3846
# Epoch [   10/   50] | d_loss: 1.1257 | g_loss: 0.9517
# Epoch [   10/   50] | d_loss: 1.0537 | g_loss: 1.4330
# Epoch [   10/   50] | d_loss: 0.9911 | g_loss: 1.5742
# Epoch [   10/   50] | d_loss: 1.1682 | g_loss: 1.1294
# Epoch [   10/   50] | d_loss: 0.9587 | g_loss: 1.6455
# Epoch [   10/   50] | d_loss: 1.2328 | g_loss: 0.6584
# Epoch [   10/   50] | d_loss: 1.1615 | g_loss: 1.1247
# Epoch [   10/   50] | d_loss: 1.0977 | g_loss: 1.4877
# Epoch [   11/   50] | d_loss: 1.0812 | g_loss: 1.2579
# Epoch [   11/   50] | d_loss: 1.1670 | g_loss: 1.5192
# Epoch [   11/   50] | d_loss: 1.1056 | g_loss: 1.1416
# Epoch [   11/   50] | d_loss: 1.0973 | g_loss: 1.3244
# Epoch [   11/   50] | d_loss: 0.9953 | g_loss: 1.3111
# Epoch [   11/   50] | d_loss: 1.0530 | g_loss: 1.1258
# Epoch [   11/   50] | d_loss: 0.9729 | g_loss: 1.5490
# Epoch [   11/   50] | d_loss: 0.9849 | g_loss: 1.2923
# Epoch [   11/   50] | d_loss: 1.1072 | g_loss: 1.0186
# Epoch [   11/   50] | d_loss: 1.0132 | g_loss: 1.2600
# Epoch [   11/   50] | d_loss: 0.9797 | g_loss: 1.6275
# Epoch [   11/   50] | d_loss: 1.0200 | g_loss: 1.9009
# Epoch [   11/   50] | d_loss: 1.0261 | g_loss: 1.0205
# Epoch [   11/   50] | d_loss: 1.0429 | g_loss: 1.3292
# Epoch [   11/   50] | d_loss: 0.9736 | g_loss: 1.6802
# Epoch [   12/   50] | d_loss: 1.0375 | g_loss: 1.0470
# Epoch [   12/   50] | d_loss: 1.0569 | g_loss: 1.4137
# Epoch [   12/   50] | d_loss: 0.9451 | g_loss: 1.8350
# Epoch [   12/   50] | d_loss: 1.0986 | g_loss: 1.1263
# Epoch [   12/   50] | d_loss: 1.0047 | g_loss: 1.0389
# Epoch [   12/   50] | d_loss: 1.1326 | g_loss: 0.9404
# Epoch [   12/   50] | d_loss: 1.0435 | g_loss: 1.3983
# Epoch [   12/   50] | d_loss: 1.0629 | g_loss: 0.9376
# Epoch [   12/   50] | d_loss: 1.1365 | g_loss: 1.6859
# Epoch [   12/   50] | d_loss: 1.0264 | g_loss: 1.3470
# Epoch [   12/   50] | d_loss: 0.8979 | g_loss: 1.1316
# Epoch [   12/   50] | d_loss: 0.9924 | g_loss: 1.2560
# Epoch [   12/   50] | d_loss: 1.0593 | g_loss: 0.9860
# Epoch [   12/   50] | d_loss: 0.9090 | g_loss: 1.3165
# Epoch [   12/   50] | d_loss: 0.9920 | g_loss: 1.1385
# Epoch [   13/   50] | d_loss: 0.9766 | g_loss: 1.4792
# Epoch [   13/   50] | d_loss: 1.0128 | g_loss: 1.1315
# Epoch [   13/   50] | d_loss: 1.0942 | g_loss: 1.0819
# Epoch [   13/   50] | d_loss: 0.9989 | g_loss: 1.6577
# Epoch [   13/   50] | d_loss: 0.8984 | g_loss: 1.3039
# Epoch [   13/   50] | d_loss: 1.0530 | g_loss: 1.3213
# Epoch [   13/   50] | d_loss: 1.0009 | g_loss: 1.0569
# Epoch [   13/   50] | d_loss: 0.8918 | g_loss: 1.6166
# Epoch [   13/   50] | d_loss: 1.0658 | g_loss: 0.9755
# Epoch [   13/   50] | d_loss: 0.9111 | g_loss: 1.1596
# Epoch [   13/   50] | d_loss: 0.9907 | g_loss: 1.1921
# Epoch [   13/   50] | d_loss: 0.9132 | g_loss: 1.3470
# Epoch [   13/   50] | d_loss: 1.4262 | g_loss: 0.3324
# Epoch [   13/   50] | d_loss: 0.9720 | g_loss: 1.5744
# Epoch [   13/   50] | d_loss: 1.0897 | g_loss: 1.9939
# Epoch [   14/   50] | d_loss: 1.0469 | g_loss: 1.5653
# Epoch [   14/   50] | d_loss: 0.9677 | g_loss: 1.2867
# Epoch [   14/   50] | d_loss: 0.9038 | g_loss: 1.6439
# Epoch [   14/   50] | d_loss: 1.2923 | g_loss: 1.4342
# Epoch [   14/   50] | d_loss: 1.1545 | g_loss: 1.5777
# Epoch [   14/   50] | d_loss: 0.9285 | g_loss: 1.7713
# Epoch [   14/   50] | d_loss: 1.0298 | g_loss: 1.7801
# Epoch [   14/   50] | d_loss: 1.0536 | g_loss: 1.5020
# Epoch [   14/   50] | d_loss: 1.0049 | g_loss: 1.2513
# Epoch [   14/   50] | d_loss: 0.9887 | g_loss: 1.8880
# Epoch [   14/   50] | d_loss: 0.8690 | g_loss: 1.4981
# Epoch [   14/   50] | d_loss: 1.3076 | g_loss: 0.5850
# Epoch [   14/   50] | d_loss: 0.8930 | g_loss: 1.7551
# Epoch [   14/   50] | d_loss: 0.9399 | g_loss: 1.4503
# Epoch [   14/   50] | d_loss: 1.3080 | g_loss: 1.3756
# Epoch [   15/   50] | d_loss: 0.9355 | g_loss: 1.2328
# Epoch [   15/   50] | d_loss: 1.0154 | g_loss: 1.5614
# Epoch [   15/   50] | d_loss: 0.8541 | g_loss: 1.1993
# Epoch [   15/   50] | d_loss: 0.9522 | g_loss: 1.4786
# Epoch [   15/   50] | d_loss: 0.8773 | g_loss: 1.5729
# Epoch [   15/   50] | d_loss: 1.2372 | g_loss: 2.4613
# Epoch [   15/   50] | d_loss: 0.8824 | g_loss: 1.3761
# Epoch [   15/   50] | d_loss: 0.8181 | g_loss: 1.6264
# Epoch [   15/   50] | d_loss: 1.0807 | g_loss: 1.5986
# Epoch [   15/   50] | d_loss: 0.9115 | g_loss: 1.7401
# Epoch [   15/   50] | d_loss: 0.9983 | g_loss: 0.9898
# Epoch [   15/   50] | d_loss: 0.8702 | g_loss: 1.2625
# Epoch [   15/   50] | d_loss: 0.9169 | g_loss: 1.1078
# Epoch [   15/   50] | d_loss: 1.0949 | g_loss: 1.6402
# Epoch [   15/   50] | d_loss: 0.9582 | g_loss: 0.9196
# Epoch [   16/   50] | d_loss: 0.9473 | g_loss: 1.2263
# Epoch [   16/   50] | d_loss: 1.0650 | g_loss: 0.9603
# Epoch [   16/   50] | d_loss: 0.8517 | g_loss: 1.8907
# Epoch [   16/   50] | d_loss: 0.9033 | g_loss: 1.2196
# Epoch [   16/   50] | d_loss: 1.0911 | g_loss: 2.1533
# Epoch [   16/   50] | d_loss: 0.8506 | g_loss: 1.9197
# Epoch [   16/   50] | d_loss: 0.9162 | g_loss: 1.7731
# Epoch [   16/   50] | d_loss: 1.0616 | g_loss: 1.2645
# Epoch [   16/   50] | d_loss: 0.9110 | g_loss: 1.5860
# Epoch [   16/   50] | d_loss: 0.9195 | g_loss: 2.0067
# Epoch [   16/   50] | d_loss: 0.9515 | g_loss: 1.9942
# Epoch [   16/   50] | d_loss: 1.0750 | g_loss: 0.9836
# Epoch [   16/   50] | d_loss: 0.9573 | g_loss: 1.7743
# Epoch [   16/   50] | d_loss: 0.9749 | g_loss: 1.5836
# Epoch [   16/   50] | d_loss: 0.8061 | g_loss: 1.8460
# Epoch [   17/   50] | d_loss: 1.0989 | g_loss: 1.1538
# Epoch [   17/   50] | d_loss: 1.1207 | g_loss: 1.2658
# Epoch [   17/   50] | d_loss: 0.8515 | g_loss: 1.8142
# Epoch [   17/   50] | d_loss: 1.1163 | g_loss: 0.9860
# Epoch [   17/   50] | d_loss: 0.9021 | g_loss: 1.9850
# Epoch [   17/   50] | d_loss: 0.9634 | g_loss: 1.6705
# Epoch [   17/   50] | d_loss: 0.7597 | g_loss: 1.6428
# Epoch [   17/   50] | d_loss: 0.8641 | g_loss: 1.1805
# Epoch [   17/   50] | d_loss: 0.9398 | g_loss: 1.2304
# Epoch [   17/   50] | d_loss: 0.9813 | g_loss: 0.8987
# Epoch [   17/   50] | d_loss: 0.9640 | g_loss: 1.6658
# Epoch [   17/   50] | d_loss: 1.0105 | g_loss: 1.0032
# Epoch [   17/   50] | d_loss: 0.8746 | g_loss: 1.8711
# Epoch [   17/   50] | d_loss: 0.7495 | g_loss: 1.7813
# Epoch [   17/   50] | d_loss: 0.8571 | g_loss: 1.3576
# Epoch [   18/   50] | d_loss: 1.0624 | g_loss: 2.5532
# Epoch [   18/   50] | d_loss: 0.8968 | g_loss: 1.3531
# Epoch [   18/   50] | d_loss: 0.8878 | g_loss: 1.5049
# Epoch [   18/   50] | d_loss: 1.1652 | g_loss: 2.4128
# Epoch [   18/   50] | d_loss: 0.8812 | g_loss: 1.2307
# Epoch [   18/   50] | d_loss: 0.8699 | g_loss: 1.5240
# Epoch [   18/   50] | d_loss: 0.8894 | g_loss: 1.2170
# Epoch [   18/   50] | d_loss: 0.9494 | g_loss: 1.1721
# Epoch [   18/   50] | d_loss: 0.7411 | g_loss: 1.9986
# Epoch [   18/   50] | d_loss: 0.8287 | g_loss: 2.5214
# Epoch [   18/   50] | d_loss: 0.7969 | g_loss: 1.6961
# Epoch [   18/   50] | d_loss: 0.8084 | g_loss: 1.2566
# Epoch [   18/   50] | d_loss: 1.0547 | g_loss: 1.4492
# Epoch [   18/   50] | d_loss: 0.8206 | g_loss: 1.6291
# Epoch [   18/   50] | d_loss: 0.9269 | g_loss: 2.4217
# Epoch [   19/   50] | d_loss: 1.0802 | g_loss: 1.2314
# Epoch [   19/   50] | d_loss: 0.7515 | g_loss: 1.7700
# Epoch [   19/   50] | d_loss: 0.9733 | g_loss: 1.0652
# Epoch [   19/   50] | d_loss: 0.9384 | g_loss: 1.5496
# Epoch [   19/   50] | d_loss: 0.7906 | g_loss: 1.1972
# Epoch [   19/   50] | d_loss: 1.0214 | g_loss: 1.0663
# Epoch [   19/   50] | d_loss: 1.0438 | g_loss: 2.5823
# Epoch [   19/   50] | d_loss: 0.9735 | g_loss: 1.5594
# Epoch [   19/   50] | d_loss: 0.8663 | g_loss: 1.4891
# Epoch [   19/   50] | d_loss: 0.8866 | g_loss: 1.2579
# Epoch [   19/   50] | d_loss: 0.8004 | g_loss: 1.8978
# Epoch [   19/   50] | d_loss: 0.8906 | g_loss: 2.3238
# Epoch [   19/   50] | d_loss: 0.9179 | g_loss: 1.3147
# Epoch [   19/   50] | d_loss: 0.8650 | g_loss: 2.3030
# Epoch [   19/   50] | d_loss: 0.8155 | g_loss: 2.1951
# Epoch [   20/   50] | d_loss: 1.0062 | g_loss: 1.2400
# Epoch [   20/   50] | d_loss: 1.0629 | g_loss: 1.5994
# Epoch [   20/   50] | d_loss: 0.8058 | g_loss: 2.4921
# Epoch [   20/   50] | d_loss: 1.3792 | g_loss: 2.8523
# Epoch [   20/   50] | d_loss: 0.7470 | g_loss: 1.3440
# Epoch [   20/   50] | d_loss: 0.8652 | g_loss: 1.3301
# Epoch [   20/   50] | d_loss: 1.7095 | g_loss: 4.2495
# Epoch [   20/   50] | d_loss: 0.7881 | g_loss: 1.7231
# Epoch [   20/   50] | d_loss: 0.8713 | g_loss: 2.0344
# Epoch [   20/   50] | d_loss: 0.8284 | g_loss: 2.0231
# Epoch [   20/   50] | d_loss: 0.7740 | g_loss: 2.1413
# Epoch [   20/   50] | d_loss: 0.6776 | g_loss: 2.1404
# Epoch [   20/   50] | d_loss: 0.8709 | g_loss: 1.3540
# Epoch [   20/   50] | d_loss: 0.7692 | g_loss: 1.5900
# Epoch [   20/   50] | d_loss: 0.7694 | g_loss: 1.4035
# Epoch [   21/   50] | d_loss: 0.8201 | g_loss: 1.4687
# Epoch [   21/   50] | d_loss: 0.9324 | g_loss: 1.2502
# Epoch [   21/   50] | d_loss: 0.7178 | g_loss: 2.3508
# Epoch [   21/   50] | d_loss: 0.7703 | g_loss: 1.7186
# Epoch [   21/   50] | d_loss: 0.8863 | g_loss: 2.1365
# Epoch [   21/   50] | d_loss: 0.7550 | g_loss: 1.9449
# Epoch [   21/   50] | d_loss: 0.7793 | g_loss: 2.0311
# Epoch [   21/   50] | d_loss: 0.7761 | g_loss: 1.2595
# Epoch [   21/   50] | d_loss: 0.7412 | g_loss: 1.5834
# Epoch [   21/   50] | d_loss: 0.9820 | g_loss: 2.5756
# Epoch [   21/   50] | d_loss: 0.7798 | g_loss: 2.6364
# Epoch [   21/   50] | d_loss: 1.2025 | g_loss: 0.4557
# Epoch [   21/   50] | d_loss: 0.8370 | g_loss: 2.3710
# Epoch [   21/   50] | d_loss: 0.9828 | g_loss: 1.7354
# Epoch [   21/   50] | d_loss: 0.8106 | g_loss: 1.6400
# Epoch [   22/   50] | d_loss: 0.7971 | g_loss: 1.1750
# Epoch [   22/   50] | d_loss: 0.8021 | g_loss: 2.1409
# Epoch [   22/   50] | d_loss: 0.7712 | g_loss: 1.5883
# Epoch [   22/   50] | d_loss: 0.7949 | g_loss: 2.5892
# Epoch [   22/   50] | d_loss: 0.7915 | g_loss: 1.5320
# Epoch [   22/   50] | d_loss: 0.7875 | g_loss: 1.2484
# Epoch [   22/   50] | d_loss: 0.7165 | g_loss: 1.8800
# Epoch [   22/   50] | d_loss: 0.8127 | g_loss: 2.0455
# Epoch [   22/   50] | d_loss: 0.9002 | g_loss: 1.9891
# Epoch [   22/   50] | d_loss: 0.6575 | g_loss: 2.4502
# Epoch [   22/   50] | d_loss: 0.6934 | g_loss: 2.4287
# Epoch [   22/   50] | d_loss: 0.9020 | g_loss: 2.4430
# Epoch [   22/   50] | d_loss: 0.8897 | g_loss: 1.5103
# Epoch [   22/   50] | d_loss: 0.8209 | g_loss: 1.7198
# Epoch [   22/   50] | d_loss: 0.8247 | g_loss: 2.3780
# Epoch [   23/   50] | d_loss: 0.7688 | g_loss: 1.1740
# Epoch [   23/   50] | d_loss: 0.7115 | g_loss: 1.5312
# Epoch [   23/   50] | d_loss: 0.7332 | g_loss: 2.2419
# Epoch [   23/   50] | d_loss: 0.7316 | g_loss: 1.8200
# Epoch [   23/   50] | d_loss: 0.7965 | g_loss: 2.6229
# Epoch [   23/   50] | d_loss: 1.2589 | g_loss: 0.6339
# Epoch [   23/   50] | d_loss: 0.8571 | g_loss: 1.0033
# Epoch [   23/   50] | d_loss: 0.7300 | g_loss: 1.6482
# Epoch [   23/   50] | d_loss: 0.7106 | g_loss: 2.4345
# Epoch [   23/   50] | d_loss: 0.7682 | g_loss: 1.5669
# Epoch [   23/   50] | d_loss: 0.8045 | g_loss: 2.3477
# Epoch [   23/   50] | d_loss: 0.8717 | g_loss: 0.9309
# Epoch [   23/   50] | d_loss: 0.7439 | g_loss: 1.9609
# Epoch [   23/   50] | d_loss: 0.7850 | g_loss: 1.3856
# Epoch [   23/   50] | d_loss: 0.7602 | g_loss: 2.5597
# Epoch [   24/   50] | d_loss: 0.6172 | g_loss: 2.0846
# Epoch [   24/   50] | d_loss: 0.8316 | g_loss: 2.2281
# Epoch [   24/   50] | d_loss: 0.7185 | g_loss: 1.9837
# Epoch [   24/   50] | d_loss: 0.9082 | g_loss: 1.1914
# Epoch [   24/   50] | d_loss: 0.5593 | g_loss: 2.0858
# Epoch [   24/   50] | d_loss: 0.7551 | g_loss: 2.7589
# Epoch [   24/   50] | d_loss: 0.8053 | g_loss: 1.9447
# Epoch [   24/   50] | d_loss: 0.6997 | g_loss: 1.9710
# Epoch [   24/   50] | d_loss: 0.6955 | g_loss: 1.9874
# Epoch [   24/   50] | d_loss: 0.7316 | g_loss: 1.7030
# Epoch [   24/   50] | d_loss: 0.6929 | g_loss: 2.3741
# Epoch [   24/   50] | d_loss: 0.7427 | g_loss: 2.3554
# Epoch [   24/   50] | d_loss: 1.2244 | g_loss: 3.5854
# Epoch [   24/   50] | d_loss: 0.7344 | g_loss: 2.2700
# Epoch [   24/   50] | d_loss: 0.7565 | g_loss: 1.4660
# Epoch [   25/   50] | d_loss: 0.9525 | g_loss: 3.0008
# Epoch [   25/   50] | d_loss: 0.7797 | g_loss: 1.8366
# Epoch [   25/   50] | d_loss: 0.6365 | g_loss: 2.1439
# Epoch [   25/   50] | d_loss: 0.7221 | g_loss: 1.8662
# Epoch [   25/   50] | d_loss: 0.6389 | g_loss: 2.1060
# Epoch [   25/   50] | d_loss: 0.6895 | g_loss: 1.9110
# Epoch [   25/   50] | d_loss: 0.6043 | g_loss: 2.0798
# Epoch [   25/   50] | d_loss: 0.6943 | g_loss: 1.7920
# Epoch [   25/   50] | d_loss: 0.7425 | g_loss: 1.9347
# Epoch [   25/   50] | d_loss: 0.7225 | g_loss: 2.0893
# Epoch [   25/   50] | d_loss: 1.1474 | g_loss: 2.9368
# Epoch [   25/   50] | d_loss: 0.7497 | g_loss: 2.0789
# Epoch [   25/   50] | d_loss: 0.7685 | g_loss: 1.7288
# Epoch [   25/   50] | d_loss: 0.7133 | g_loss: 1.7465
# Epoch [   25/   50] | d_loss: 0.6215 | g_loss: 2.2195
# Epoch [   26/   50] | d_loss: 0.6309 | g_loss: 2.2016
# Epoch [   26/   50] | d_loss: 0.7236 | g_loss: 2.1488
# Epoch [   26/   50] | d_loss: 0.7053 | g_loss: 1.5604
# Epoch [   26/   50] | d_loss: 0.8501 | g_loss: 0.9871
# Epoch [   26/   50] | d_loss: 0.7253 | g_loss: 1.8864
# Epoch [   26/   50] | d_loss: 0.6778 | g_loss: 1.8035
# Epoch [   26/   50] | d_loss: 0.7320 | g_loss: 1.8441
# Epoch [   26/   50] | d_loss: 0.7803 | g_loss: 2.9070
# Epoch [   26/   50] | d_loss: 0.6552 | g_loss: 2.1108
# Epoch [   26/   50] | d_loss: 0.6946 | g_loss: 2.0896
# Epoch [   26/   50] | d_loss: 1.7016 | g_loss: 0.1763
# Epoch [   26/   50] | d_loss: 0.7137 | g_loss: 2.6886
# Epoch [   26/   50] | d_loss: 0.8290 | g_loss: 2.9376
# Epoch [   26/   50] | d_loss: 0.6784 | g_loss: 2.4911
# Epoch [   26/   50] | d_loss: 0.8742 | g_loss: 2.5447
# Epoch [   27/   50] | d_loss: 0.7266 | g_loss: 1.6703
# Epoch [   27/   50] | d_loss: 2.9755 | g_loss: 0.1597
# Epoch [   27/   50] | d_loss: 0.7537 | g_loss: 2.1310
# Epoch [   27/   50] | d_loss: 0.6831 | g_loss: 2.5873
# Epoch [   27/   50] | d_loss: 0.8473 | g_loss: 2.0166
# Epoch [   27/   50] | d_loss: 0.6242 | g_loss: 2.0789
# Epoch [   27/   50] | d_loss: 0.6719 | g_loss: 2.0080
# Epoch [   27/   50] | d_loss: 0.8672 | g_loss: 2.1660
# Epoch [   27/   50] | d_loss: 0.7354 | g_loss: 1.9573
# Epoch [   27/   50] | d_loss: 0.7793 | g_loss: 1.9784
# Epoch [   27/   50] | d_loss: 0.6867 | g_loss: 2.3748
# Epoch [   27/   50] | d_loss: 1.1846 | g_loss: 3.9336
# Epoch [   27/   50] | d_loss: 0.5914 | g_loss: 2.1142
# Epoch [   27/   50] | d_loss: 0.7789 | g_loss: 2.4011
# Epoch [   27/   50] | d_loss: 1.1654 | g_loss: 1.1388
# Epoch [   28/   50] | d_loss: 1.3940 | g_loss: 3.3197
# Epoch [   28/   50] | d_loss: 0.6704 | g_loss: 2.0770
# Epoch [   28/   50] | d_loss: 0.6444 | g_loss: 1.9923
# Epoch [   28/   50] | d_loss: 0.6274 | g_loss: 1.9574
# Epoch [   28/   50] | d_loss: 0.7132 | g_loss: 1.8300
# Epoch [   28/   50] | d_loss: 0.7075 | g_loss: 2.0777
# Epoch [   28/   50] | d_loss: 1.4188 | g_loss: 3.2331
# Epoch [   28/   50] | d_loss: 0.8946 | g_loss: 1.1828
# Epoch [   28/   50] | d_loss: 0.6869 | g_loss: 2.0298
# Epoch [   28/   50] | d_loss: 0.7099 | g_loss: 1.9743
# Epoch [   28/   50] | d_loss: 0.6647 | g_loss: 2.8130
# Epoch [   28/   50] | d_loss: 0.7714 | g_loss: 2.1403
# Epoch [   28/   50] | d_loss: 0.6717 | g_loss: 1.6130
# Epoch [   28/   50] | d_loss: 1.4689 | g_loss: 4.1080
# Epoch [   28/   50] | d_loss: 0.7054 | g_loss: 2.0767
# Epoch [   29/   50] | d_loss: 0.6910 | g_loss: 1.8143
# Epoch [   29/   50] | d_loss: 0.5705 | g_loss: 2.5994
# Epoch [   29/   50] | d_loss: 0.6926 | g_loss: 1.7356
# Epoch [   29/   50] | d_loss: 0.6169 | g_loss: 1.9695
# Epoch [   29/   50] | d_loss: 0.6673 | g_loss: 2.2645
# Epoch [   29/   50] | d_loss: 0.7088 | g_loss: 2.3010
# Epoch [   29/   50] | d_loss: 0.6963 | g_loss: 2.5555
# Epoch [   29/   50] | d_loss: 0.8192 | g_loss: 1.7534
# Epoch [   29/   50] | d_loss: 0.6445 | g_loss: 2.5308
# Epoch [   29/   50] | d_loss: 0.6990 | g_loss: 1.8889
# Epoch [   29/   50] | d_loss: 0.7206 | g_loss: 2.1999
# Epoch [   29/   50] | d_loss: 0.6478 | g_loss: 1.9865
# Epoch [   29/   50] | d_loss: 0.8886 | g_loss: 1.7061
# Epoch [   29/   50] | d_loss: 0.6686 | g_loss: 2.4209
# Epoch [   29/   50] | d_loss: 0.6006 | g_loss: 2.0228
# Epoch [   30/   50] | d_loss: 0.6848 | g_loss: 2.2865
# Epoch [   30/   50] | d_loss: 0.9585 | g_loss: 3.3580
# Epoch [   30/   50] | d_loss: 0.6603 | g_loss: 2.2611
# Epoch [   30/   50] | d_loss: 0.6859 | g_loss: 2.0653
# Epoch [   30/   50] | d_loss: 0.7134 | g_loss: 1.8594
# Epoch [   30/   50] | d_loss: 0.6289 | g_loss: 2.9872
# Epoch [   30/   50] | d_loss: 0.7180 | g_loss: 2.8104
# Epoch [   30/   50] | d_loss: 0.7864 | g_loss: 1.4508
# Epoch [   30/   50] | d_loss: 0.6630 | g_loss: 2.7658
# Epoch [   30/   50] | d_loss: 0.6173 | g_loss: 3.0734
# Epoch [   30/   50] | d_loss: 0.7312 | g_loss: 2.8073
# Epoch [   30/   50] | d_loss: 0.6781 | g_loss: 2.7138
# Epoch [   30/   50] | d_loss: 0.7010 | g_loss: 2.2182
# Epoch [   30/   50] | d_loss: 0.6535 | g_loss: 2.5315
# Epoch [   30/   50] | d_loss: 0.6300 | g_loss: 2.4781
# Epoch [   31/   50] | d_loss: 0.7387 | g_loss: 1.7695
# Epoch [   31/   50] | d_loss: 0.7559 | g_loss: 1.4545
# Epoch [   31/   50] | d_loss: 1.6181 | g_loss: 0.7322
# Epoch [   31/   50] | d_loss: 0.6365 | g_loss: 2.9176
# Epoch [   31/   50] | d_loss: 0.6129 | g_loss: 2.8060
# Epoch [   31/   50] | d_loss: 1.6214 | g_loss: 0.5703
# Epoch [   31/   50] | d_loss: 0.7084 | g_loss: 1.5893
# Epoch [   31/   50] | d_loss: 0.5535 | g_loss: 2.4203
# Epoch [   31/   50] | d_loss: 0.6042 | g_loss: 2.3792
# Epoch [   31/   50] | d_loss: 0.5435 | g_loss: 2.2179
# Epoch [   31/   50] | d_loss: 0.6054 | g_loss: 1.6409
# Epoch [   31/   50] | d_loss: 0.8745 | g_loss: 2.4397
# Epoch [   31/   50] | d_loss: 0.6800 | g_loss: 2.2292
# Epoch [   31/   50] | d_loss: 0.6999 | g_loss: 2.0973
# Epoch [   31/   50] | d_loss: 0.6546 | g_loss: 2.0507
# Epoch [   32/   50] | d_loss: 0.5881 | g_loss: 1.9198
# Epoch [   32/   50] | d_loss: 0.5882 | g_loss: 2.4018
# Epoch [   32/   50] | d_loss: 0.6377 | g_loss: 2.6409
# Epoch [   32/   50] | d_loss: 0.5870 | g_loss: 3.0844
# Epoch [   32/   50] | d_loss: 0.6707 | g_loss: 2.3902
# Epoch [   32/   50] | d_loss: 0.6994 | g_loss: 1.6074
# Epoch [   32/   50] | d_loss: 0.6148 | g_loss: 2.6826
# Epoch [   32/   50] | d_loss: 0.6405 | g_loss: 2.0638
# Epoch [   32/   50] | d_loss: 0.6561 | g_loss: 2.3283
# Epoch [   32/   50] | d_loss: 0.6128 | g_loss: 1.7927
# Epoch [   32/   50] | d_loss: 0.7992 | g_loss: 2.5974
# Epoch [   32/   50] | d_loss: 0.6844 | g_loss: 1.7314
# Epoch [   32/   50] | d_loss: 0.5727 | g_loss: 2.4677
# Epoch [   32/   50] | d_loss: 0.6794 | g_loss: 1.9011
# Epoch [   32/   50] | d_loss: 0.7185 | g_loss: 1.2322
# Epoch [   33/   50] | d_loss: 0.8013 | g_loss: 1.8802
# Epoch [   33/   50] | d_loss: 0.7439 | g_loss: 1.5729
# Epoch [   33/   50] | d_loss: 0.7720 | g_loss: 1.1000
# Epoch [   33/   50] | d_loss: 0.7616 | g_loss: 1.9913
# Epoch [   33/   50] | d_loss: 0.7689 | g_loss: 1.4099
# Epoch [   33/   50] | d_loss: 0.6528 | g_loss: 2.6796
# Epoch [   33/   50] | d_loss: 0.6516 | g_loss: 2.1682
# Epoch [   33/   50] | d_loss: 0.6826 | g_loss: 1.9824
# Epoch [   33/   50] | d_loss: 0.5667 | g_loss: 2.3517
# Epoch [   33/   50] | d_loss: 0.7515 | g_loss: 2.4720
# Epoch [   33/   50] | d_loss: 0.6263 | g_loss: 1.8270
# Epoch [   33/   50] | d_loss: 0.6620 | g_loss: 2.7650
# Epoch [   33/   50] | d_loss: 0.7873 | g_loss: 1.8409
# Epoch [   33/   50] | d_loss: 0.7324 | g_loss: 1.1747
# Epoch [   33/   50] | d_loss: 0.6449 | g_loss: 1.9115
# Epoch [   34/   50] | d_loss: 0.5522 | g_loss: 2.6433
# Epoch [   34/   50] | d_loss: 0.5714 | g_loss: 2.7613
# Epoch [   34/   50] | d_loss: 0.6953 | g_loss: 3.1011
# Epoch [   34/   50] | d_loss: 0.6613 | g_loss: 2.4238
# Epoch [   34/   50] | d_loss: 0.7211 | g_loss: 3.2867
# Epoch [   34/   50] | d_loss: 0.6383 | g_loss: 2.0277
# Epoch [   34/   50] | d_loss: 0.7104 | g_loss: 1.6376
# Epoch [   34/   50] | d_loss: 0.7076 | g_loss: 2.4150
# Epoch [   34/   50] | d_loss: 0.5883 | g_loss: 2.2542
# Epoch [   34/   50] | d_loss: 0.5991 | g_loss: 2.4867
# Epoch [   34/   50] | d_loss: 0.5699 | g_loss: 2.1970
# Epoch [   34/   50] | d_loss: 0.6458 | g_loss: 2.2329
# Epoch [   34/   50] | d_loss: 0.7426 | g_loss: 1.7411
# Epoch [   34/   50] | d_loss: 0.5800 | g_loss: 2.2520
# Epoch [   34/   50] | d_loss: 1.0516 | g_loss: 2.3945
# Epoch [   35/   50] | d_loss: 1.1723 | g_loss: 3.5887
# Epoch [   35/   50] | d_loss: 0.7441 | g_loss: 2.2218
# Epoch [   35/   50] | d_loss: 0.5923 | g_loss: 2.7046
# Epoch [   35/   50] | d_loss: 0.6186 | g_loss: 2.1449
# Epoch [   35/   50] | d_loss: 0.5984 | g_loss: 2.8636
# Epoch [   35/   50] | d_loss: 0.6164 | g_loss: 1.8796
# Epoch [   35/   50] | d_loss: 0.5502 | g_loss: 2.4040
# Epoch [   35/   50] | d_loss: 0.7152 | g_loss: 3.2293
# Epoch [   35/   50] | d_loss: 0.6347 | g_loss: 1.6405
# Epoch [   35/   50] | d_loss: 0.6642 | g_loss: 2.1990
# Epoch [   35/   50] | d_loss: 0.5624 | g_loss: 3.1089
# Epoch [   35/   50] | d_loss: 0.6627 | g_loss: 1.6258
# Epoch [   35/   50] | d_loss: 0.7160 | g_loss: 1.8004
# Epoch [   35/   50] | d_loss: 0.6707 | g_loss: 2.9532
# Epoch [   35/   50] | d_loss: 0.8096 | g_loss: 1.7238
# Epoch [   36/   50] | d_loss: 0.6400 | g_loss: 2.9621
# Epoch [   36/   50] | d_loss: 0.5313 | g_loss: 2.2870
# Epoch [   36/   50] | d_loss: 0.8361 | g_loss: 3.6514
# Epoch [   36/   50] | d_loss: 0.5578 | g_loss: 2.6394
# Epoch [   36/   50] | d_loss: 0.6192 | g_loss: 1.9732
# Epoch [   36/   50] | d_loss: 0.7145 | g_loss: 1.8396
# Epoch [   36/   50] | d_loss: 0.6130 | g_loss: 1.9859
# Epoch [   36/   50] | d_loss: 0.6687 | g_loss: 1.8757
# Epoch [   36/   50] | d_loss: 0.5565 | g_loss: 2.4134
# Epoch [   36/   50] | d_loss: 0.6219 | g_loss: 2.1590
# Epoch [   36/   50] | d_loss: 0.6505 | g_loss: 2.0588
# Epoch [   36/   50] | d_loss: 0.6291 | g_loss: 2.7142
# Epoch [   36/   50] | d_loss: 0.6253 | g_loss: 3.6737
# Epoch [   36/   50] | d_loss: 1.0565 | g_loss: 1.0935
# Epoch [   36/   50] | d_loss: 0.5383 | g_loss: 3.2018
# Epoch [   37/   50] | d_loss: 0.5810 | g_loss: 2.7826
# Epoch [   37/   50] | d_loss: 0.6092 | g_loss: 1.9331
# Epoch [   37/   50] | d_loss: 0.5268 | g_loss: 2.7065
# Epoch [   37/   50] | d_loss: 0.4826 | g_loss: 3.5504
# Epoch [   37/   50] | d_loss: 1.0806 | g_loss: 1.3600
# Epoch [   37/   50] | d_loss: 0.8843 | g_loss: 2.8373
# Epoch [   37/   50] | d_loss: 0.6014 | g_loss: 2.8203
# Epoch [   37/   50] | d_loss: 0.5666 | g_loss: 2.7660
# Epoch [   37/   50] | d_loss: 0.7695 | g_loss: 2.6495
# Epoch [   37/   50] | d_loss: 0.5894 | g_loss: 1.7801
# Epoch [   37/   50] | d_loss: 0.5293 | g_loss: 2.7723
# Epoch [   37/   50] | d_loss: 0.6702 | g_loss: 2.6464
# Epoch [   37/   50] | d_loss: 0.6776 | g_loss: 1.7738
# Epoch [   37/   50] | d_loss: 0.5681 | g_loss: 3.7162
# Epoch [   37/   50] | d_loss: 0.5665 | g_loss: 2.4387
# Epoch [   38/   50] | d_loss: 0.5294 | g_loss: 2.3516
# Epoch [   38/   50] | d_loss: 0.5952 | g_loss: 2.2362
# Epoch [   38/   50] | d_loss: 0.5204 | g_loss: 2.5013
# Epoch [   38/   50] | d_loss: 0.4847 | g_loss: 3.0381
# Epoch [   38/   50] | d_loss: 0.6188 | g_loss: 2.3232
# Epoch [   38/   50] | d_loss: 0.6619 | g_loss: 1.8393
# Epoch [   38/   50] | d_loss: 0.6197 | g_loss: 2.5411
# Epoch [   38/   50] | d_loss: 0.5520 | g_loss: 2.5390
# Epoch [   38/   50] | d_loss: 0.5852 | g_loss: 2.2572
# Epoch [   38/   50] | d_loss: 0.7579 | g_loss: 1.1040
# Epoch [   38/   50] | d_loss: 0.6319 | g_loss: 2.2697
# Epoch [   38/   50] | d_loss: 0.6129 | g_loss: 2.6328
# Epoch [   38/   50] | d_loss: 0.5565 | g_loss: 2.6088
# Epoch [   38/   50] | d_loss: 0.5173 | g_loss: 3.2199
# Epoch [   38/   50] | d_loss: 0.5703 | g_loss: 2.4856
# Epoch [   39/   50] | d_loss: 0.5476 | g_loss: 2.2637
# Epoch [   39/   50] | d_loss: 0.5501 | g_loss: 2.7405
# Epoch [   39/   50] | d_loss: 0.6281 | g_loss: 1.7010
# Epoch [   39/   50] | d_loss: 0.5801 | g_loss: 3.0631
# Epoch [   39/   50] | d_loss: 0.5343 | g_loss: 2.8949
# Epoch [   39/   50] | d_loss: 0.5617 | g_loss: 3.1511
# Epoch [   39/   50] | d_loss: 0.6361 | g_loss: 2.7856
# Epoch [   39/   50] | d_loss: 0.7427 | g_loss: 2.6603
# Epoch [   39/   50] | d_loss: 0.5983 | g_loss: 2.5133
# Epoch [   39/   50] | d_loss: 0.6862 | g_loss: 1.7177
# Epoch [   39/   50] | d_loss: 0.4886 | g_loss: 2.3389
# Epoch [   39/   50] | d_loss: 0.5852 | g_loss: 2.4243
# Epoch [   39/   50] | d_loss: 0.5504 | g_loss: 2.1118
# Epoch [   39/   50] | d_loss: 0.5920 | g_loss: 2.2027
# Epoch [   39/   50] | d_loss: 0.5751 | g_loss: 2.6593
# Epoch [   40/   50] | d_loss: 0.6563 | g_loss: 3.3047
# Epoch [   40/   50] | d_loss: 1.2064 | g_loss: 4.1082
# Epoch [   40/   50] | d_loss: 0.5584 | g_loss: 2.5445
# Epoch [   40/   50] | d_loss: 0.6202 | g_loss: 1.9553
# Epoch [   40/   50] | d_loss: 0.6233 | g_loss: 2.5933
# Epoch [   40/   50] | d_loss: 0.5333 | g_loss: 2.7699
# Epoch [   40/   50] | d_loss: 1.0075 | g_loss: 1.5544
# Epoch [   40/   50] | d_loss: 0.8897 | g_loss: 1.4154
# Epoch [   40/   50] | d_loss: 0.6253 | g_loss: 2.6874
# Epoch [   40/   50] | d_loss: 0.6153 | g_loss: 2.0275
# Epoch [   40/   50] | d_loss: 0.6418 | g_loss: 2.1507
# Epoch [   40/   50] | d_loss: 0.5433 | g_loss: 3.4773
# Epoch [   40/   50] | d_loss: 0.5551 | g_loss: 2.9489
# Epoch [   40/   50] | d_loss: 0.5888 | g_loss: 2.6212
# Epoch [   40/   50] | d_loss: 0.6099 | g_loss: 3.1435
# Epoch [   41/   50] | d_loss: 0.5948 | g_loss: 3.1661
# Epoch [   41/   50] | d_loss: 0.5186 | g_loss: 2.7281
# Epoch [   41/   50] | d_loss: 0.6405 | g_loss: 1.8693
# Epoch [   41/   50] | d_loss: 0.5842 | g_loss: 2.9475
# Epoch [   41/   50] | d_loss: 0.5878 | g_loss: 2.4729
# Epoch [   41/   50] | d_loss: 2.4395 | g_loss: 0.9726
# Epoch [   41/   50] | d_loss: 0.5941 | g_loss: 2.4301
# Epoch [   41/   50] | d_loss: 0.6081 | g_loss: 2.7171
# Epoch [   41/   50] | d_loss: 0.5901 | g_loss: 2.4982
# Epoch [   41/   50] | d_loss: 0.6349 | g_loss: 2.1988
# Epoch [   41/   50] | d_loss: 0.5905 | g_loss: 2.4304
# Epoch [   41/   50] | d_loss: 0.6795 | g_loss: 3.4007
# Epoch [   41/   50] | d_loss: 0.5375 | g_loss: 2.1663
# Epoch [   41/   50] | d_loss: 0.5872 | g_loss: 1.3324
# Epoch [   41/   50] | d_loss: 0.5593 | g_loss: 1.9922
# Epoch [   42/   50] | d_loss: 0.7260 | g_loss: 2.8002
# Epoch [   42/   50] | d_loss: 0.4853 | g_loss: 2.3536
# Epoch [   42/   50] | d_loss: 0.7260 | g_loss: 3.1666
# Epoch [   42/   50] | d_loss: 0.6043 | g_loss: 2.3182
# Epoch [   42/   50] | d_loss: 0.5085 | g_loss: 3.3255
# Epoch [   42/   50] | d_loss: 1.2096 | g_loss: 1.3121
# Epoch [   42/   50] | d_loss: 0.5940 | g_loss: 2.2612
# Epoch [   42/   50] | d_loss: 0.5285 | g_loss: 3.4018
# Epoch [   42/   50] | d_loss: 1.1203 | g_loss: 1.4317
# Epoch [   42/   50] | d_loss: 0.4817 | g_loss: 2.5884
# Epoch [   42/   50] | d_loss: 0.5363 | g_loss: 2.5340
# Epoch [   42/   50] | d_loss: 0.5291 | g_loss: 2.4283
# Epoch [   42/   50] | d_loss: 0.6954 | g_loss: 3.7598
# Epoch [   42/   50] | d_loss: 0.4908 | g_loss: 2.2987
# Epoch [   42/   50] | d_loss: 0.5901 | g_loss: 2.7898
# Epoch [   43/   50] | d_loss: 0.5747 | g_loss: 2.4582
# Epoch [   43/   50] | d_loss: 0.5989 | g_loss: 3.0741
# Epoch [   43/   50] | d_loss: 0.5793 | g_loss: 2.2933
# Epoch [   43/   50] | d_loss: 0.5192 | g_loss: 2.4451
# Epoch [   43/   50] | d_loss: 0.6042 | g_loss: 2.1327
# Epoch [   43/   50] | d_loss: 0.6199 | g_loss: 2.2360
# Epoch [   43/   50] | d_loss: 0.5878 | g_loss: 1.8677
# Epoch [   43/   50] | d_loss: 0.5683 | g_loss: 2.3198
# Epoch [   43/   50] | d_loss: 1.0327 | g_loss: 3.1987
# Epoch [   43/   50] | d_loss: 0.6904 | g_loss: 1.7834
# Epoch [   43/   50] | d_loss: 0.5908 | g_loss: 2.0314
# Epoch [   43/   50] | d_loss: 0.7224 | g_loss: 2.8709
# Epoch [   43/   50] | d_loss: 1.0857 | g_loss: 3.4154
# Epoch [   43/   50] | d_loss: 0.6073 | g_loss: 2.8877
# Epoch [   43/   50] | d_loss: 0.4958 | g_loss: 3.2055
# Epoch [   44/   50] | d_loss: 0.5099 | g_loss: 3.0649
# Epoch [   44/   50] | d_loss: 0.4698 | g_loss: 3.2379
# Epoch [   44/   50] | d_loss: 0.5486 | g_loss: 2.2716
# Epoch [   44/   50] | d_loss: 0.5124 | g_loss: 3.2676
# Epoch [   44/   50] | d_loss: 0.5604 | g_loss: 2.5088
# Epoch [   44/   50] | d_loss: 1.9736 | g_loss: 0.8518
# Epoch [   44/   50] | d_loss: 0.5054 | g_loss: 2.3918
# Epoch [   44/   50] | d_loss: 0.5158 | g_loss: 2.9912
# Epoch [   44/   50] | d_loss: 0.6516 | g_loss: 2.0073
# Epoch [   44/   50] | d_loss: 0.5614 | g_loss: 1.9796
# Epoch [   44/   50] | d_loss: 0.5261 | g_loss: 3.2203
# Epoch [   44/   50] | d_loss: 0.5230 | g_loss: 3.0117
# Epoch [   44/   50] | d_loss: 0.5008 | g_loss: 3.1365
# Epoch [   44/   50] | d_loss: 0.4783 | g_loss: 3.0160
# Epoch [   44/   50] | d_loss: 0.5317 | g_loss: 3.4095
# Epoch [   45/   50] | d_loss: 0.4968 | g_loss: 2.9127
# Epoch [   45/   50] | d_loss: 0.5659 | g_loss: 2.2022
# Epoch [   45/   50] | d_loss: 0.5622 | g_loss: 2.6652
# Epoch [   45/   50] | d_loss: 0.5708 | g_loss: 3.5296
# Epoch [   45/   50] | d_loss: 0.5606 | g_loss: 2.5484
# Epoch [   45/   50] | d_loss: 0.5673 | g_loss: 2.1204
# Epoch [   45/   50] | d_loss: 1.0435 | g_loss: 1.3388
# Epoch [   45/   50] | d_loss: 0.7410 | g_loss: 1.5098
# Epoch [   45/   50] | d_loss: 0.5190 | g_loss: 3.1946
# Epoch [   45/   50] | d_loss: 0.7575 | g_loss: 1.7177
# Epoch [   45/   50] | d_loss: 0.5561 | g_loss: 2.8618
# Epoch [   45/   50] | d_loss: 0.5746 | g_loss: 2.7646
# Epoch [   45/   50] | d_loss: 0.6711 | g_loss: 3.6109
# Epoch [   45/   50] | d_loss: 1.3201 | g_loss: 0.7909
# Epoch [   45/   50] | d_loss: 0.5594 | g_loss: 3.4073
# Epoch [   46/   50] | d_loss: 0.5299 | g_loss: 3.4871
# Epoch [   46/   50] | d_loss: 0.5904 | g_loss: 3.5191
# Epoch [   46/   50] | d_loss: 0.6685 | g_loss: 1.8975
# Epoch [   46/   50] | d_loss: 0.5170 | g_loss: 2.0593
# Epoch [   46/   50] | d_loss: 0.5717 | g_loss: 2.1970
# Epoch [   46/   50] | d_loss: 0.5056 | g_loss: 3.2337
# Epoch [   46/   50] | d_loss: 0.6310 | g_loss: 1.7783
# Epoch [   46/   50] | d_loss: 0.5911 | g_loss: 2.0209
# Epoch [   46/   50] | d_loss: 1.8806 | g_loss: 3.6645
# Epoch [   46/   50] | d_loss: 0.6345 | g_loss: 3.6328
# Epoch [   46/   50] | d_loss: 0.5662 | g_loss: 2.8173
# Epoch [   46/   50] | d_loss: 0.4815 | g_loss: 3.2474
# Epoch [   46/   50] | d_loss: 0.5508 | g_loss: 2.6961
# Epoch [   46/   50] | d_loss: 0.5944 | g_loss: 2.4707
# Epoch [   46/   50] | d_loss: 0.5201 | g_loss: 2.9894
# Epoch [   47/   50] | d_loss: 0.5067 | g_loss: 2.5818
# Epoch [   47/   50] | d_loss: 0.6731 | g_loss: 1.9303
# Epoch [   47/   50] | d_loss: 0.5291 | g_loss: 2.9100
# Epoch [   47/   50] | d_loss: 0.6520 | g_loss: 1.7889
# Epoch [   47/   50] | d_loss: 0.7471 | g_loss: 2.1570
# Epoch [   47/   50] | d_loss: 0.6304 | g_loss: 1.9954
# Epoch [   47/   50] | d_loss: 0.7392 | g_loss: 2.2436
# Epoch [   47/   50] | d_loss: 0.5279 | g_loss: 2.8213
# Epoch [   47/   50] | d_loss: 0.5182 | g_loss: 2.8862
# Epoch [   47/   50] | d_loss: 0.5391 | g_loss: 2.7162
# Epoch [   47/   50] | d_loss: 0.7372 | g_loss: 3.2495
# Epoch [   47/   50] | d_loss: 0.5798 | g_loss: 2.2102
# Epoch [   47/   50] | d_loss: 0.4968 | g_loss: 3.0109
# Epoch [   47/   50] | d_loss: 0.6326 | g_loss: 3.1324
# Epoch [   47/   50] | d_loss: 0.5695 | g_loss: 1.9026
# Epoch [   48/   50] | d_loss: 0.5971 | g_loss: 1.9493
# Epoch [   48/   50] | d_loss: 0.5035 | g_loss: 2.6930
# Epoch [   48/   50] | d_loss: 0.5457 | g_loss: 2.7633
# Epoch [   48/   50] | d_loss: 0.5213 | g_loss: 2.6781
# Epoch [   48/   50] | d_loss: 0.6286 | g_loss: 1.8184
# Epoch [   48/   50] | d_loss: 1.9240 | g_loss: 0.8217
# Epoch [   48/   50] | d_loss: 0.5157 | g_loss: 2.4893
# Epoch [   48/   50] | d_loss: 0.7016 | g_loss: 1.6286
# Epoch [   48/   50] | d_loss: 0.5385 | g_loss: 2.3756
# Epoch [   48/   50] | d_loss: 0.4855 | g_loss: 2.5781
# Epoch [   48/   50] | d_loss: 0.5538 | g_loss: 2.5473
# Epoch [   48/   50] | d_loss: 0.6448 | g_loss: 2.5616
# Epoch [   48/   50] | d_loss: 0.5502 | g_loss: 2.7471
# Epoch [   48/   50] | d_loss: 0.5812 | g_loss: 2.2399
# Epoch [   48/   50] | d_loss: 0.5172 | g_loss: 3.7840
# Epoch [   49/   50] | d_loss: 0.5241 | g_loss: 2.6134
# Epoch [   49/   50] | d_loss: 0.5320 | g_loss: 2.2399
# Epoch [   49/   50] | d_loss: 5.0208 | g_loss: 0.3715
# Epoch [   49/   50] | d_loss: 0.5616 | g_loss: 2.8181
# Epoch [   49/   50] | d_loss: 0.5563 | g_loss: 3.3230
# Epoch [   49/   50] | d_loss: 0.5518 | g_loss: 2.2062
# Epoch [   49/   50] | d_loss: 0.5552 | g_loss: 2.7700
# Epoch [   49/   50] | d_loss: 0.5612 | g_loss: 3.0099
# Epoch [   49/   50] | d_loss: 0.5445 | g_loss: 2.0688
# Epoch [   49/   50] | d_loss: 0.6298 | g_loss: 2.5599
# Epoch [   49/   50] | d_loss: 0.4715 | g_loss: 3.0309
# Epoch [   49/   50] | d_loss: 0.6051 | g_loss: 3.5155
# Epoch [   49/   50] | d_loss: 0.6000 | g_loss: 2.3383
# Epoch [   49/   50] | d_loss: 1.0593 | g_loss: 1.8988
# Epoch [   49/   50] | d_loss: 0.5529 | g_loss: 2.7156
# Epoch [   50/   50] | d_loss: 0.6106 | g_loss: 2.4134
# Epoch [   50/   50] | d_loss: 0.4878 | g_loss: 2.2362
# Epoch [   50/   50] | d_loss: 0.5162 | g_loss: 2.7009
# Epoch [   50/   50] | d_loss: 0.4727 | g_loss: 3.0709
# Epoch [   50/   50] | d_loss: 0.5753 | g_loss: 3.2515
# Epoch [   50/   50] | d_loss: 0.6115 | g_loss: 3.6872
# Epoch [   50/   50] | d_loss: 0.5081 | g_loss: 2.4912
# Epoch [   50/   50] | d_loss: 0.5708 | g_loss: 1.8175
# Epoch [   50/   50] | d_loss: 0.5517 | g_loss: 3.3544
# Epoch [   50/   50] | d_loss: 0.5666 | g_loss: 3.5719
# Epoch [   50/   50] | d_loss: 0.5385 | g_loss: 2.6331
# Epoch [   50/   50] | d_loss: 0.5479 | g_loss: 2.7423
# Epoch [   50/   50] | d_loss: 0.5273 | g_loss: 2.6137
# Epoch [   50/   50] | d_loss: 0.4624 | g_loss: 3.1184
# Epoch [   50/   50] | d_loss: 0.5449 | g_loss: 1.5392

# %% [markdown]
# ## Training loss
#
# Plot the training losses for the generator and discriminator, recorded after each epoch.

# %%
fig, ax = plt.subplots()
losses = np.array(losses)
plt.plot(losses.T[0], label='Discriminator', alpha=0.5)
plt.plot(losses.T[1], label='Generator', alpha=0.5)
plt.title("Training Losses")
plt.legend()

# %% [markdown]
# ## Generator samples from training
#
# View samples of images from the generator, and answer a question about the strengths and weaknesses of your trained models.

# %%
# helper function for viewing a list of passed in sample images
def view_samples(epoch, samples):
    fig, axes = plt.subplots(figsize=(16,4), nrows=2, ncols=8, sharey=True, sharex=True)
    for ax, img in zip(axes.flatten(), samples[epoch]):
        img = img.detach().cpu().numpy()
        img = np.transpose(img, (1, 2, 0))
        img = ((img + 1)*255 / (2)).astype(np.uint8)
        ax.xaxis.set_visible(False)
        ax.yaxis.set_visible(False)
        im = ax.imshow(img.reshape((32,32,3)))

# %%
# Load samples from generator, taken while training
with open('train_samples.pkl', 'rb') as f:
    samples = pkl.load(f)

# %%
_ = view_samples(-1, samples)

# %% [markdown]
# ### Question: What do you notice about your generated samples and how might you improve this model?
# When you answer this question, consider the following factors:
# * The dataset is biased; it is made of "celebrity" faces that are mostly white
# * Model size; larger models have the opportunity to learn more features in a data feature space
# * Optimization strategy; optimizers and number of epochs affect your final result

# %% [markdown]
# **Answer:** (Write your answer in this cell)
# 1. Human faces are slightly different based on races and genders.Current data sets are biased since most of them are white. It would be better to collect same portions of differnt races and genders for the network to learn.
#
# 2. It is better to have more quality data, so it would be nice to have large *good quality* photos.
#     * current photos are cropped on the chin level and do not show full face
#     * some does wear hats or glasses
#     * To generate pure faces , it would be better to collect better quality photo to detect full face pattern from forehead to chin.
#
# 3. As for Optimizer, created two separate Adam optimizer for the discriminator D and generator G. Tried epochs= 5, the Generator loss was around 5 , Discriminator does not seem to be decreased. When epochs=50 , Discriminator loss shows obvious decreasing tendency.

# %% [markdown]
# ### Submitting This Project
# When submitting this project, make sure to run all the cells before saving the notebook. Save the notebook file as "dlnd_face_generation.ipynb" and save it as a HTML file under "File" -> "Download as". Include the "problem_unittests.py" files in your submission.

# %%
# !jupyter nbconvert "dlnd_face_generation.ipynb"
# Out:
# [NbConvertApp] Converting notebook dlnd_face_generation.ipynb to html
# [NbConvertApp] Writing 535819 bytes to dlnd_face_generation.html

# %%
# !!apt-get -y update && apt-get-install -y zip
# !zip project4.zip -r . -i dlnd_face_generation.ipynb dlnd_face_generation.html problem_unittests.py
# Out:
# updating: dlnd_face_generation.html (deflated 69%)
# updating: dlnd_face_generation.ipynb (deflated 46%)
# updating: problem_unittests.py (deflated 68%)
